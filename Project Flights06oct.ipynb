# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
path_flights="C:/Users/w130156/Downloads/Projet Flights/flights.csv"
FLIGHTS = pd.read_csv(path_flights)
print("flights")
FLIGHTS
# Out:
# flights
#         year  month  day dep_time  sched_dep_time dep_delay arr_time  \
# 0       2021      1    1      517             515         2      830
# 1       2021      1    1      533             529         4      850
# 2       2021      1    1      542             540         2      923
# 3       2021      1    1      544             545        -1     1004
# 4       2021      1    1      554             600        -6      812
# ...      ...    ...  ...      ...             ...       ...      ...
# 252699  2021      7    3     1059            1100        -1     1214
# 252700  2021      7    3     1059            1100        -1     1207
# 252701  2021      7    3     1101            1110        -9     1305
# 252702  2021      7    3     1105            1055        10     1435
# 252703  2021      7    3     1107            1100         7     1220
#
#         sched_arr_time arr_delay carrier  flight tailnum origin dest air_time  \
# ...

# %%
path_airlines = "C:/Users/w130156/Downloads/Projet Flights/airlines.csv"
AIRLINES = pd.read_csv(path_airlines)
print("airlines")
AIRLINES
# Out:
# airlines
#    carrier                         name
# 0       9E            Endeavor Air Inc.
# 1       AA       American Airlines Inc.
# 2       AS         Alaska Airlines Inc.
# 3       B6              JetBlue Airways
# 4       DL         Delta Air Lines Inc.
# 5       EV     ExpressJet Airlines Inc.
# 6       F9       Frontier Airlines Inc.
# 7       FL  AirTran Airways Corporation
# 8       HA       Hawaiian Airlines Inc.
# 9       MQ                    Envoy Air
# 10      OO        SkyWest Airlines Inc.
# 11      UA        United Air Lines Inc.
# 12      US              US Airways Inc.
# 13      VX               Virgin America
# 14      WN       Southwest Airlines Co.
# 15      YV           Mesa Airlines Inc.

# %%
path_airports ="C:/Users/w130156/Downloads/Projet Flights/airports.csv"
AIRPORTS = pd.read_csv(path_airports)
print("airports")
AIRPORTS
# Out:
# airports
#       faa                           name        lat         lon   alt  tz dst  \
# 0     04G              Lansdowne Airport  41.130472  -80.619583  1044  -5   A
# 1     06A  Moton Field Municipal Airport  32.460572  -85.680028   264  -6   A
# 2     06C            Schaumburg Regional  41.989341  -88.101243   801  -6   A
# 3     06N                Randall Airport  41.431912  -74.391561   523  -5   A
# 4     09J          Jekyll Island Airport  31.074472  -81.427778    11  -5   A
# ...   ...                            ...        ...         ...   ...  ..  ..
# 1453  ZUN                     Black Rock  35.083228 -108.791778  6454  -7   A
# 1454  ZVE         New Haven Rail Station  41.298669  -72.925992     7  -5   A
# 1455  ZWI      Wilmington Amtrak Station  39.736667  -75.551667     0  -5   A
# 1456  ZWU       Washington Union Station  38.897460  -77.006430    76  -5   A
# 1457  ZYP                   Penn Station  40.750500  -73.993500    35  -5   A
#
# ...

# %%
path_planes="C:/Users/w130156/Downloads/Projet Flights/planes.csv"
PLANES = pd.read_csv(path_planes)
print("planes")
PLANES
# Out:
# planes
#      tailnum  year                     type                   manufacturer  \
# 0     N10156  2004  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002  Fixed wing multi engine                        EMBRAER
# ...      ...   ...                      ...                            ...
# 3317  N997AT  2002  Fixed wing multi engine                         BOEING
# 3318  N997DL  1992  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3319  N998AT  2002  Fixed wing multi engine                         BOEING
# 3320  N998DL  1992  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3321  N999DN  1992  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
#           model  engines  seats speed     engine
# ...

# %%
path_weather="C:/Users/w130156/Downloads/Projet Flights/weather.csv"
WEATHER = pd.read_csv(path_weather)
print("weather")
WEATHER
# Out:
# weather
#       origin  year  month  day  hour   temp   dewp  humid wind_dir  \
# 0        EWR  2021      1    1     0  37.04  21.92  53.97      230
# 1        EWR  2021      1    1     1  37.04  21.92  53.97      230
# 2        EWR  2021      1    1     2  37.94  21.92  52.09      230
# 3        EWR  2021      1    1     3  37.94     23  54.51      230
# 4        EWR  2021      1    1     4  37.94  24.08  57.04      240
# ...      ...   ...    ...  ...   ...    ...    ...    ...      ...
# 26125    LGA  2021     12   30    19  35.96  19.94  51.78      340
# 26126    LGA  2021     12   30    20  33.98  17.06  49.51      330
# 26127    LGA  2021     12   30    21     32  15.08  49.19      340
# 26128    LGA  2021     12   30    22  30.92  12.92  46.74      320
# 26129    LGA  2021     12   30    23  28.94  10.94  46.41      330
#
#                wind_speed           wind_gust  precip pressure  visib  \
# 0      10.357019999999999  11.918651475599997     0.0   1013.9   10.0
# ...

# %%
path_weather_with_3_doublons ="C:/Users/w130156/Downloads/Projet Flights/weather_with_3_doublons.csv"
WEATHER_WITH_3_DOUBLONS = pd.read_csv(path_weather_with_3_doublons)
print("weather_with_3_doublons")
WEATHER_WITH_3_DOUBLONS
# Out:
# weather_with_3_doublons
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     1  39.02  26.06  59.37     270.0
# 1        EWR  2013      1    1     2  39.02  26.96  61.63     250.0
# 2        EWR  2013      1    1     3  39.02  28.04  64.43     240.0
# 3        EWR  2013      1    1     4  39.92  28.04  62.21     250.0
# 4        EWR  2013      1    1     5  39.02  28.04  64.43     260.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 26110    LGA  2013     12   30    14  35.96  19.94  51.78     340.0
# 26111    LGA  2013     12   30    15  33.98  17.06  49.51     330.0
# 26112    LGA  2013     12   30    16  32.00  15.08  49.19     340.0
# 26113    LGA  2013     12   30    17  30.92  12.92  46.74     320.0
# 26114    LGA  2013     12   30    18  28.94  10.94  46.41     330.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# ...

# %%
def no_airports():
    no_airports = AIRPORTS['name'].drop_duplicates(keep='first').count()
    return no_airports
no_aeroports()
# Out:
# 1440

# %%
# 1.1.2
def no_airports_departures():
    cancel_flights_table = FLIGHTS[FLIGHTS[['air_time', 'dep_time', 'arr_time']].eq(' ').all(axis=1)]
    cancel_flights = cancel_flights_table["origin"].count()
    cancel_flights
    sched_flights = FLIGHTS["origin"].count()
    sched_flights
    no_departs = squed_flights - cancel_flights
    no_departs
    return no_departs
no_airports_departures()
# Out:
# 246223

# %%
#1.1.3
def no_airports_destination():
    destination = FLIGHTS['dest'].drop_duplicates(keep='first').count()
    return destination
no_airports_destination()
# Out:
# 103

# %%
# 1.3.1.
def no_carrier():
    compagnies = AIRLINES['carrier'].drop_duplicates(keep='first').count()
    return compagnies
no_carrier()
# Out:
# 16

# %%
# 1.3.2
def no_planes():
    planes = PLANES['tailnum'].drop_duplicates(keep='first').count()
    return avions
no_avions()
# Out:
# 3322

# %%
def flight_cancelled():
    print(
        len(FLIGHTS.loc[FLIGHTS["dep_time"] == " "]
            .loc[FLIGHTS["arr_time"] == " "]
            .loc[FLIGHTS["air_time"] == " "]
            ))


flight_cancelled()
# Out:
# 6481

# %%
# 1.3.3
def flight_cancelled():
    flight_cancelled_table = FLIGHTS[FLIGHTS[['air_time', 'dep_time', 'arr_time']].eq(' ').all(axis=1)]
    no_flight_cancelled = flight_cancelled_table["origin"].count()
    return no_flight_cancelled
flight_cancelled()
# Out:
# 6481

# %%
#2.1.
def busiest_departure_airport():
    aeroport = FLIGHTS["origin"].mode()
    return aeroport
busiest_departure_airport()
# Out:
# 0    EWR
# Name: origin, dtype: object

# %%
# Out:
#         year  month  day dep_time  sched_dep_time dep_delay arr_time  \
# 0       2021      1    1      517             515         2      830
# 1       2021      1    1      533             529         4      850
# 2       2021      1    1      542             540         2      923
# 3       2021      1    1      544             545        -1     1004
# 4       2021      1    1      554             600        -6      812
# ...      ...    ...  ...      ...             ...       ...      ...
# 252699  2021      7    3     1059            1100        -1     1214
# 252700  2021      7    3     1059            1100        -1     1207
# 252701  2021      7    3     1101            1110        -9     1305
# 252702  2021      7    3     1105            1055        10     1435
# 252703  2021      7    3     1107            1100         7     1220
#
#         sched_arr_time arr_delay carrier  ...  minute             time_hour  \
# ...

# %%
# 2.2. 
def most_frequent_destinations():
    merged_tables = FLIGHTS.merge(AIRPORTS,how ='left', left_on ='dest', right_on ='faa')
    frequent_destinations = merged_tables['name'].value_counts(normalize=True).head(10)
    return frequent_destinations

most_frequent_destinations()
# Out:
# Hartsfield Jackson Atlanta Intl       0.052416
# Chicago Ohare Intl                    0.051233
# Los Angeles Intl                      0.048160
# General Edward Lawrence Logan Intl    0.046804
# Orlando Intl                          0.043067
# Charlotte Douglas Intl                0.042302
# San Francisco Intl                    0.039391
# Fort Lauderdale Hollywood Intl        0.038233
# Miami Intl                            0.036188
# Ronald Reagan Washington Natl         0.029904
# Name: name, dtype: float64

# %%
# 2.3.
def less_frequent_destinations():
    destinations_moins_prisées = merged_tables['name'].value_counts(normalize=True).tail(10)
    return destinations_moins_prisées
less_frequent_destinations()
# Out:
# Charlottesville-Albemarle    0.000126
# Jackson Hole Airport         0.000101
# Gallatin Field               0.000081
# Palm Springs Intl            0.000077
# Key West Intl                0.000069
# Cherry Capital Airport       0.000065
# Montrose Regional Airport    0.000061
# Yampa Valley                 0.000061
# South Bend Rgnl              0.000016
# Blue Grass                   0.000004
# Name: name, dtype: float64

# %%
# 2.4.
def planes_taken_off_the_most():
    planes_most  = FLIGHTS['tailnum'].value_counts().head(10)
    return planes_most
planes_taken_off_the_most()
# Out:
#           1973
# N725MQ     443
# N723MQ     394
# N713MQ     385
# N722MQ     378
# N711MQ     376
# N258JB     332
# N353JB     316
# N542MQ     310
# N351JB     310
# Name: tailnum, dtype: int64

# %%
# 2.5 
def planes_taken_off_the_least():
    les_10_avions_moins = FLIGHTS['tailnum'].value_counts().tail(10)
    return les_10_avions_moins
planes_taken_off_the_least()
# Out:
# N914DN    1
# N7ACAA    1
# N302AS    1
# N585AS    1
# N7AXAA    1
# N907DA    1
# N941FR    1
# N350SW    1
# N320AS    1
# N352NB    1
# Name: tailnum, dtype: int64

# %%
# 4.1
def landed_in_Houston():
    landed_Houston = FLIGHTS.loc[FLIGHTS['dest'].isin(['IAH','HOU'])]
    return landed_Houston
landed_in_Houston()
# Out:
#         year  month  day dep_time  sched_dep_time dep_delay arr_time  \
# 0       2021      1    1      517             515         2      830
# 1       2021      1    1      533             529         4      850
# 32      2021      1    1      623             627        -4      933
# 81      2021      1    1      728             732        -4     1041
# 89      2021      1    1      739             739         0     1104
# ...      ...    ...  ...      ...             ...       ...      ...
# 252543  2021      7    3      811             815        -4     1054
# 252581  2021      7    3      846             853        -7     1129
# 252594  2021      7    3      855             855         0     1137
# 252677  2021      7    3     1025            1030        -5     1300
# 252692  2021      7    3     1052            1100        -8     1328
#
#         sched_arr_time arr_delay carrier  flight tailnum origin dest air_time  \
# ...

# %%
# 4.2
def NYC_to_Seattle():
    NYC_to_Seattle_table = FLIGHTS.loc[FLIGHTS['dest'].isin(["SEA"])]
    NYC_Seattle = NYC_to_Seattle_table['dest'].value_counts()
    return NYC_Seattle
NYC_to_Seattle()
# Out:
# SEA    2736
# Name: dest, dtype: int64

# %%
# 4.3 
def carrier_NYC_to_Seattle():
    NYC_Seattle_carrier = NYC_to_Seattle_table['carrier'].drop_duplicates(keep='first').count()
    return NYC_Seattle_carrier
carrier_NYC_to_Seattle()
# Out:
# 5

# %%
# 4.4 
def plane_NYC_to_Seattle():
    flights_sea = FLIGHTS[FLIGHTS['dest']=='SEA']
    return flights_sea['tailnum'].nunique()
plane_NYC_to_Seattle()
# NYC_vers_Seattle_avions
# Out:
# 857

# %%
# 7
def destinations_exclusive():
    groupby_destination_table = FLIGHTS.groupby(by="dest").nunique()
    exclusive  = groupby_destination_table[groupby_destination_table['carrier'] == 1 ]
    return list(exclusive.index.values) 

destinations_exclusive()
# Out:
# ['ABQ',
#  'ACK',
#  'ALB',
#  'BHM',
#  'BUR',
#  'BZN',
#  'CAK',
#  'CHO',
#  'CRW',
#  'EYW',
#  'GSO',
#  'HDN',
#  'ILM',
#  'LEX',
#  'LGB',
#  'MDW',
#  'MSN',
#  'MTJ',
#  'MYR',
#  'OAK',
#  'OKC',
#  'PSE',
#  'PSP',
#  'PVD',
#  'SAV',
#  'SBN',
#  'SMF',
#  'SNA',
#  'TUL']

# %%
# 8
def flights_UAD():
    United_American_Delta_table  = FLIGHTS.loc[FLIGHTS['carrier'].isin(["UA", "AA", "DL"])]
    return United_American_Delta_table 
flights_UAD()
# Out:
#         year  month  day dep_time  sched_dep_time dep_delay arr_time  \
# 0       2021      1    1      517             515         2      830
# 1       2021      1    1      533             529         4      850
# 2       2021      1    1      542             540         2      923
# 4       2021      1    1      554             600        -6      812
# 5       2021      1    1      554             558        -4      740
# ...      ...    ...  ...      ...             ...       ...      ...
# 252689  2021      7    3     1048            1055        -7     1330
# 252692  2021      7    3     1052            1100        -8     1328
# 252695  2021      7    3     1056            1055         1     1359
# 252696  2021      7    3     1057            1059        -2     1249
# 252698  2021      7    3     1059            1100        -1     1340
#
#         sched_arr_time arr_delay carrier  flight tailnum origin dest air_time  \
# ...
